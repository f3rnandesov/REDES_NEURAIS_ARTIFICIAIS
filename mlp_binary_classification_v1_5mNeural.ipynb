# %% [markdown]
# <a href="https://colab.research.google.com/github/f3rnandesov/REDES_NEURAIS_ARTIFICIAIS/blob/main/mlp_binary_classification_v1_5mNeural.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])
y = np.array([
    [0],
    [1],
    [1],
    [1]
])

# %%
model = Sequential()
model.add(Dense(5000000, input_dim= 2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=50, verbose=1)
print(f"Previsões: \n {model.predict(X)}")
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 1.0000 - loss: 0.1392
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step - accuracy: 1.0000 - loss: 0.1279
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step - accuracy: 1.0000 - loss: 0.1153
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step - accuracy: 1.0000 - loss: 0.1018
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 1.0000 - loss: 0.0879
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 1.0000 - loss: 0.0739
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step - accuracy: 1.0000 - loss: 0.0605
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 1.0000 - loss: 0.0483
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 1.0000 - loss: 0.0375
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 1.0000 - loss: 9.3916e-04
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 7.2832e-04
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step - accuracy: 1.0000 - loss: 5.7343e-04
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 1.0000 - loss: 4.5831e-04
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 1.0000 - loss: 3.7172e-04
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 1.0000 - loss: 3.0581e-04
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 805ms/step - accuracy: 1.0000 - loss: 2.5505e-04
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step - accuracy: 1.0000 - loss: 2.1550e-04
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step - accuracy: 1.0000 - loss: 1.8435e-04
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.5956e-04
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 1.0000 - loss: 1.3963e-04
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - accuracy: 1.0000 - loss: 1.2345e-04
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 1.0000 - loss: 1.1020e-04
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 1.0000 - loss: 9.9257e-05
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 1.0000 - loss: 9.0149e-05
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step - accuracy: 1.0000 - loss: 8.2511e-05
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 1.0000 - loss: 7.6063e-05
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - accuracy: 1.0000 - loss: 7.0584e-05
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 1.0000 - loss: 6.5901e-05
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 1.0000 - loss: 6.1876e-05
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - loss: 5.8398e-05
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 788ms/step - accuracy: 1.0000 - loss: 5.5379e-05
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - accuracy: 1.0000 - loss: 5.2747e-05
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 1.0000 - loss: 5.0442e-05
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 1.0000 - loss: 4.8416e-05
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 1.0000 - loss: 4.6629e-05
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 1.0000 - loss: 4.5046e-05
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step - accuracy: 1.0000 - loss: 4.3641e-05
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step - accuracy: 1.0000 - loss: 4.2389e-05
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 1.0000 - loss: 4.1271e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Previsões:
#  [[1.6097225e-04]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]]
